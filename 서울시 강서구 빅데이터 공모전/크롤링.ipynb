# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

base_url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query='

keyword = input("검색어를 입력하세요 : ")
search_url = base_url + keyword

chrome_path = "c:/py_temp1/chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
driver.get(search_url)
time.sleep(3)

for i in range(3) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
items = soup.select(".api_txt_lines.total_tit")

for e, item in enumerate(items,1) :
    result = print(f"{e} : {item.text}")
    result

driver.quit()
# Out:
# 검색어를 입력하세요 : 봉제산공원
# C:\Users\sos35\AppData\Local\Temp\ipykernel_34416\372437441.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# 1 : 용왕산~달마을공원~봉제산~검덕산~우장산~수명산을 걷다. - 4.봉제산 구간
# 2 : 봉제산 둘레길 근린공원 서울 강서구 산책하기 좋은 등산
# 3 : 강서구 근린공원 추천_봉제산 근린공원
# 4 : 서서울둘레길#2, 까치산역에서 가양역까지 : 봉제산 ~ 우장산 ~ 서울식물원 ~ 물재생공원 ~ 치현산/개화산...
# 5 : 강서구 물놀이터❥아이들이 놀기 좋은 봉제산 근린공원 태양광장 물놀이장
# 6 : 서울 동네산6. 20202.3.9. 목동 용왕산(엄지산), 목3동 달맞이공원. 봉제산은 다음에.
# 7 : 봉제산 근린공원 벚꽃 구경하기
# 8 : 서울 I 강서구 봉제산 둘레길 _ 숲속 북카페 / 숲속 놀이터 / 법성사 / 철쭉동산 / 산마루공원 / 국기봉
# 9 : 봉제산 공원 산책
# 10 : 한강 접근성 따라 집 값 차이 ‘억’?!
# 11 : 까치산 숨겨진 벚꽃명소 봉제산근린공원
# 12 : LG전자-서울시, 자율주행 통신기술로 어린이 교통안전 지킴이 나서
# 13 : 서울 강서구 봉제산공원 백구 목격
# 14 : 도시공원 일몰제 후폭풍… 소유주 줄소송 현실화
# 15 : 강서구 봉제산 근린공원에서 가벼운 산책해봐요
# 16 : [강서구 추천공원] 봉제산공원(鳳蹄山公園)
# 17 : 우수한 생활 인프라 올인원 아파트…강서구 등촌 두산위브 분양!
# 18 : 봉제산 둘레길 산마루공원 산책
# 19 : 주말 산책하기 좋은 곳 화곡동 공원 봉제산 근린공원
# 20 : 강서구 봉제산 공원 진도믹스 유기견 목격
# ...

# %%
# url까지 같이
base_url = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query='

keyword = input("검색어를 입력하세요 : ")
search_url = base_url + keyword

chrome_path = "c:/py_temp1/chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
driver.get(search_url)
time.sleep(3)

for i in range(3) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

items = soup.select(".total_wrap.api_ani_send")

for rank_num, item in enumerate(items,1) :
    print(f"<<{rank_num}>>")
    ad = item.select_one(".link_ad")
    if ad :
        print("광고입니다.")
        continue
        
    blog_title = item.select_one(".sub_txt.sub_name").text
    print(f"{blog_title}")
    
    post_title = item.select_one(".api_txt_lines.total_tit._cross_trigger")
    print(f"{post_title.text}")
    
    print(f"{post_title.get('href')}")
    print(f"{post_title['href']}")
    
    print()

driver.quit()
# Out:
# 검색어를 입력하세요 : 봉제산공원
# C:\Users\sos35\AppData\Local\Temp\ipykernel_34416\3626856452.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# <<1>>
# 마음을 비우면 보이는 것들
# 용왕산~달마을공원~봉제산~검덕산~우장산~수명산을 걷다. - 4.봉제산 구간
# https://blog.naver.com/domi2014/222666026283
# https://blog.naver.com/domi2014/222666026283
#
# <<2>>
# 내일이 기대되는 일기
# 봉제산 둘레길 근린공원 서울 강서구 산책하기 좋은 등산
# https://blog.naver.com/vocalistkym/222932817712
# https://blog.naver.com/vocalistkym/222932817712
#
# <<3>>
# 명상, 세상과 함께 웃다
# 강서구 근린공원 추천_봉제산 근린공원
# https://blog.naver.com/knsb_meditation/222882181276
# https://blog.naver.com/knsb_meditation/222882181276
#
# <<4>>
# 살아가는동안
# 서서울둘레길#2, 까치산역에서 가양역까지 : 봉제산 ~ 우장산 ~ 서울식물원 ~ 물재생공원 ~ 치현산/개화산...
# https://blog.naver.com/jeonghj66/223027486896
# https://blog.naver.com/jeonghj66/223027486896
#
# <<5>>
# 알콩달콩 율이네♥
# 강서구 물놀이터❥아이들이 놀기 좋은 봉제산 근린공원 태양광장 물놀이장
# https://blog.naver.com/lovely_1022/222828173779
# ...

# %% [markdown]
# # 네이버 크롤링

# %%
ID = "TblbrEX41dlN64ncla7U"
KEY = "yvKnkmiAWk"

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = ID
client_secret = KEY
encText = urllib.parse.quote("봉제산공원")

def create_url(start) :
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display=100' + '&start=' + str(start)
    return url

url = create_url(1)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    results = response_body.decode("utf-8")
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 15 Mar 2023 00:44:32 +0900",
# 	"total":6278,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"<b>봉제산<\/b>근린<b>공원<\/b>\/무장애숲길\/<b>봉제산<\/b>책쉼터",
# 			"link":"https:\/\/blog.naver.com\/happywasoon\/223042463175",
# 			"description":"(요금은 5분에 50원으로 1시간17분 있었더니 800원이 나왔어요) 이상은 제가 본 달라진 봉제산근린공원모습이었어요. 이렇게 달라진 모습을 보며 편한길을 따라 산책을 했어요 봄을 맞은 <b>봉제산공원<\/b>은 겨울에... ",
# 			"bloggername":"꿈꾸는 숲의 블로그",
# 			"bloggerlink":"blog.naver.com\/happywasoon",
# 			"postdate":"20230312"
# 		},
# 		{
# 			"title":"용왕산~달마을<b>공원<\/b>~<b>봉제산<\/b>~검덕산~우장산~수명산을 걷다. - 4.... ",
# 			"link":"https:\/\/blog.naver.com\/domi2014\/222666026283",
# 			"description":"달마을<b>공원<\/b>을 지나 대일고등학교 앞에서 <b>봉제산<\/b>들머리를 향해 걸어간다. 건너편으로 대일고등학교가 보이고 대일고교 왼쪽에 있는 길로 간다. 삼거리에서 왼쪽으로 가면 <b>봉제산<\/b>들머리가 나온다. 들머리에서... ",
# 			"bloggername":"마음을 비우면 보이는 것들",
# 			"bloggerlink":"blog.naver.com\/domi2014",
# 			"postdate":"20220307"
# 		},
# 		{
# ...

# %%
import json
items = json.loads(results)["items"]

# %%
items[0]
# Out:
# {'title': '<b>봉제산</b> 둘레길 근린<b>공원</b> 서울 강서구 산책하기 좋은 등산',
#  'link': 'https://blog.naver.com/vocalistkym/222932817712',
#  'description': '아침 산책으론 딱 좋은 그런 등산? 이었답니다. . 다리도 다 풀린 것 같으니 이젠 어디 산을 가볼까? #봉제산 #봉제산근린공원 #봉제산둘레길 #봉제산도서관 #<b>봉제산공원</b> #산책 #등산',
#  'bloggername': '내일이 기대되는 일기',
#  'bloggerlink': 'blog.naver.com/vocalistkym',
#  'postdate': '20221119'}

# %%
for i in range(1,1001,100) :
    url = create_url(i)
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        results = response_body.decode("utf-8")
        items = json.loads(results)["items"]
        for item in items :
            f = open("크롤링.txt", "a", encoding="utf8")
            title = item['title']
            description = item["description"]
            
            title = title.replace('<b>', '')
            title = title.replace('</b>', '')
            description = description.replace('<b>', '')
            description = description.replace('</b>', '')
            
            f.write(title + '\n')
            f.write(description + '\n') 
            f.close()

# %% [markdown]
# # 위에 과정 하나의 함수로

# %%
def naver_api(where, what, how) : # where은 뉴스, 블로그, 카페 등등, what은 찾고 싶은 검색어, how는 어떤 파일로 저장할지
    encText = urllib.parse.quote(what)
    for i in range(1,1001,100) :
        url = "https://openapi.naver.com/v1/search/" + where + "?query=" + encText + '&display=100' + '&start=' + str(i)
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            results = response_body.decode("utf-8")
            items = json.loads(results)["items"]
            for item in items :
                f = open(how, "a", encoding="utf8")
                title = item['title']
                description = item["description"]

                title = title.replace('<b>', '')
                title = title.replace('</b>', '')
                description = description.replace('<b>', '')
                description = description.replace('</b>', '')

                f.write(title + '\n')
                f.write(description + '\n') 
                f.close()

# %%
naver_api('blog', '까치산공원','까치산공원.txt')

# %%
naver_api('blog', '봉제산공원','봉제산공원.txt')

# %%
naver_api('blog', '우장근린공원','우장근린공원.txt')

# %% [markdown]
# # 형태소 분석(코랩)

# %%
f = open("봉제산공원.txt", "r", encoding='utf8')
txt = f.readlines()
f.close()

# %%
txt
# Out:
# ['봉제산 둘레길 근린공원 서울 강서구 산책하기 좋은 등산\n',
#  '아침 산책으론 딱 좋은 그런 등산? 이었답니다. . 다리도 다 풀린 것 같으니 이젠 어디 산을 가볼까? #봉제산 #봉제산근린공원 #봉제산둘레길 #봉제산도서관 #봉제산공원 #산책 #등산\n',
#  '용왕산~달마을공원~봉제산~검덕산~우장산~수명산을 걷다. - 4.... \n',
#  '달마을공원을 지나 대일고등학교 앞에서 봉제산들머리를 향해 걸어간다. 건너편으로 대일고등학교가 보이고 대일고교 왼쪽에 있는 길로 간다. 삼거리에서 왼쪽으로 가면 봉제산들머리가 나온다. 들머리에서... \n',
#  '강서구 근린공원 추천_봉제산 근린공원\n',
#  '봉제산 공원을 검색하면 봉제산 둘레길 주변의 수많은 근린공원들이 나와서 헷갈리실 텐데요. 오늘 소개해 드릴 공원은 아래 지도에 표기해 드린 자연체험학습원이 있는 봉제산 근린공원입니다. 봉제산이... \n',
#  '9. 목동 용왕산(엄지산), 목3동 달맞이공원. 봉제산은 다음에.\n',
#  '바로 봉제산으로 갈 예정이었는데 지도를 보니 목3동 속에 달맞이공원이란 조그만 공원이 보여서 이 공원을 거쳐 봉제산에 가기로 하고 연립주택이 가득한 시가지로 들어선다. 목동에 아파트 외에 이렇게나 많은... \n',
#  '겸재[설평기려]의 우장산 근린공원과 봉제산을 걷다(2023, 1... \n',
#  '우장근린공원을 거쳐 봉제산까지 걸어 보기로 한다, 산대장 후덕 친구의 의견으로 눈오는 날 이곳을 걸을 예정 이었으나 2022년 테마 산행인 서울둘레길을 완주하다 보니 눈 오는 날을 맞추지 못하고 겨울이... \n',
#  '봉제산 근린공원 벚꽃 구경하기\n',
#  '동네 공원이라고 생각하기에는 봉제산공원 은 봉제산에 있기 때문에 꽤 높고 넓은데요. 연못도 있고 이렇게 예쁜 물레방아도 있어요. 지금은 왜 안 돌아가고 있을까요? 짠~ 낮에는 이렇게 물레방아가... \n',
#  '강서구 화곡동 대형견 산책하기 좋은곳 - 봉제산근린공원\n',
# ...

# %% [markdown]
# # 워드클라우드

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np

import os
import re
from PIL import Image
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
f = open('morph_txt', 'r', encoding='UTF-8')
txt = f.readlines()
f.close()

# %%
txt
# Out:
# ['봉제산\n',
#  '둘레길\n',
#  '근\n',
#  '린\n',
#  '공원\n',
#  '서울\n',
#  '강서구\n',
#  '산책\n',
#  '하기\n',
#  '좋은\n',
#  '등산\n',
#  '\n',
#  '\n',
#  '아침\n',
#  '산책\n',
#  '으론\n',
#  '딱\n',
#  '좋은\n',
#  '그런\n',
#  '등산\n',
#  '?\n',
#  '이었답니다\n',
#  '.\n',
#  '.\n',
#  '다리\n',
#  '도\n',
#  '다\n',
#  '풀린\n',
#  '것\n',
#  '같으니\n',
#  '이\n',
#  '젠\n',
#  '어디\n',
#  '산\n',
#  '을\n',
#  '가볼까\n',
#  '?\n',
#  '#봉제산\n',
#  '#봉제산근린공원\n',
#  '#봉제산둘레길\n',
#  '#봉제산도서관\n',
#  '#봉제산공원\n',
#  '#산책\n',
#  '#등산\n',
#  '\n',
#  '\n',
#  '용왕산\n',
#  '~\n',
#  '달\n',
#  '마을\n',
#  '공원\n',
#  '~\n',
#  '봉제산\n',
#  '~\n',
#  '검\n',
#  '덕산\n',
#  '~\n',
#  '우장산\n',
#  '~\n',
#  '수\n',
#  '명산\n',
#  '을\n',
#  '걷다\n',
#  '-\n',
#  '4\n',
#  '달\n',
#  '마을\n',
#  '공원\n',
#  '을\n',
#  '지나\n',
#  '대일\n',
#  '고등학교\n',
#  '앞\n',
#  '에서\n',
#  '봉제산\n',
#  '들머리\n',
#  '를\n',
#  '향\n',
#  '해\n',
#  '걸어간다\n',
#  '.\n',
#  '건너편\n',
#  '으로\n',
#  '대\n',
#  '일\n',
#  '고등학교\n',
#  '가\n',
#  '보이\n',
#  '고\n',
#  '대일\n',
# ...

# %%
new_txt = []
for i in txt :
    new_txt.append(i.replace('\n',''))

# %%
new_txt
# Out:
# ['봉제산',
#  '둘레길',
#  '근',
#  '린',
#  '공원',
#  '서울',
#  '강서구',
#  '산책',
#  '하기',
#  '좋은',
#  '등산',
#  '',
#  '',
#  '아침',
#  '산책',
#  '으론',
#  '딱',
#  '좋은',
#  '그런',
#  '등산',
#  '?',
#  '이었답니다',
#  '.',
#  '.',
#  '다리',
#  '도',
#  '다',
#  '풀린',
#  '것',
#  '같으니',
#  '이',
#  '젠',
#  '어디',
#  '산',
#  '을',
#  '가볼까',
#  '?',
#  '#봉제산',
#  '#봉제산근린공원',
#  '#봉제산둘레길',
#  '#봉제산도서관',
#  '#봉제산공원',
#  '#산책',
#  '#등산',
#  '',
#  '',
#  '용왕산',
#  '~',
#  '달',
#  '마을',
#  '공원',
#  '~',
#  '봉제산',
#  '~',
#  '검',
#  '덕산',
#  '~',
#  '우장산',
#  '~',
#  '수',
#  '명산',
#  '을',
#  '걷다',
#  '-',
#  '4',
#  '달',
#  '마을',
#  '공원',
#  '을',
#  '지나',
#  '대일',
#  '고등학교',
#  '앞',
#  '에서',
#  '봉제산',
#  '들머리',
#  '를',
#  '향',
#  '해',
#  '걸어간다',
#  '.',
#  '건너편',
#  '으로',
#  '대',
#  '일',
#  '고등학교',
#  '가',
#  '보이',
#  '고',
#  '대일',
#  '고교',
#  '왼쪽',
#  '에',
#  '있는',
#  '길',
#  '로',
#  '간다',
#  '.',
#  '삼거리',
#  '에서',
#  '왼쪽',
#  '으로',
#  '가면',
#  '봉제산',
#  '들머리',
#  '가',
#  '나온다',
#  '.',
#  '들머리',
#  '에서',
#  '...',
# ...

# %%
str_txt = ''
for i in new_txt :
    str_txt = str_txt + i + ' '

# %%
from collections import Counter
Counter(new_txt).most_common()
# Out:
# [('봉제산', 2327),
#  ('', 1936),
#  ('공원', 1687),
#  ('.', 1332),
#  ('...', 1147),
#  ('이', 962),
#  ('에', 944),
#  (',', 944),
#  ('을', 824),
#  ('의', 555),
#  ('근', 547),
#  ('린', 545),
#  ('은', 448),
#  ('가', 426),
#  ('(', 418),
#  ('-', 415),
#  ('으로', 396),
#  ('들', 389),
#  ('~', 384),
#  ('에서', 373),
#  ('둘레길', 367),
#  ('도', 333),
#  ('강서구', 324),
#  ('를', 321),
#  (')', 305),
#  ('과', 262),
#  ('로', 246),
#  ('한', 235),
#  ('산마루', 228),
#  ('산', 220),
#  ('[', 218),
#  (']', 218),
#  ('아침', 207),
#  ('산책', 202),
#  ('는', 197),
#  ('있는', 174),
#  (';', 165),
#  ('화곡동', 159),
#  ('곳', 158),
#  ('서울', 157),
#  ('길', 151),
#  ('자연', 141),
#  ('코스', 141),
#  ('만', 134),
#  ('&', 134),
#  ('입니다', 129),
#  ('등', 129),
#  ('수', 127),
#  ('에는', 127),
#  ('좋은', 125),
#  ('원', 122),
#  ('터', 120),
#  ('집', 116),
#  ('생태', 114),
#  ('화곡', 113),
#  (':', 112),
#  ('!', 111),
#  ('하고', 110),
#  ('와', 109),
#  ('오늘', 108),
#  ('운동', 107),
#  ('고', 104),
#  ('1', 104),
#  ('2', 103),
# ...

# %%
stop = ["있다", "~~", "도", "이", "에", "을", "의"]
stopwords = set(stop)

# %%
stopwords.add("봉제산")
stopwords.add("")
stopwords.add("공원")
stopwords.add("근")
stopwords.add("린")
stopwords.add("은")
stopwords.add("가")
stopwords.add("(")
stopwords.add("-")
stopwords.add("으로")
stopwords.add("들")
stopwords.add("에서")
stopwords.add("도")
stopwords.add("를")
stopwords.add(")")
stopwords.add("로")
stopwords.add("한")
stopwords.add("[")
stopwords.add("]")
stopwords.add("는")
stopwords.add("&")
stopwords.add("강서구")
stopwords.add("입니다")
stopwords.add("에는")
stopwords.add("과")
stopwords.add("등")
stopwords.add("곳")
stopwords.add("있는")
stopwords.add("하고")
stopwords.add("이다")
stopwords.add("와")
stopwords.add("하는")
stopwords.add("다")

# %%
circle_mask = np.array(Image.open("picture.png")) # 배경이미지를 불러와서 numpy array로 변환

wc = WordCloud(font_path = 'C:/Users/sos35/AppData/Local/Microsoft/Windows/Fonts/NanumGothicBold.otf', max_font_size=100, max_words=100,
width=800, height=400, background_color="white",stopwords=stopwords, margin=10, random_state=1, contour_color='black').generate(str_txt)

wc.to_file("a_new_hope.png")
plt.axis("off")
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 까치산 공원

# %%
f = open('morph2_txt', 'r', encoding='UTF-8')
txt = f.readlines()
f.close()

# %%
new_txt = []
for i in txt :
    new_txt.append(i.replace('\n',''))

# %%
new_txt
# Out:
# ['구일역',
#  '에서',
#  '까치산역',
#  '까지',
#  '...',
#  '지',
#  '양산',
#  '~',
#  '능골산',
#  '/',
#  '서',
#  '서',
#  '울',
#  '호수',
#  '공원',
#  ',',
#  '19',
#  'km',
#  '',
#  '',
#  '매봉산',
#  '~',
#  '지',
#  '양산',
#  '국기봉',
#  '~',
#  '능골산',
#  '~',
#  '서',
#  '서',
#  '울',
#  '호수',
#  '공원',
#  '~',
#  '까치산역',
#  '골목',
#  '안쪽',
#  '의',
#  '온',
#  '수',
#  '근',
#  '린',
#  '공원',
#  '에서',
#  '매봉산',
#  '으로',
#  '올라간다',
#  '매봉산',
#  '은',
#  '해발',
#  '110',
#  'm',
#  '.',
#  '서울',
#  '시내',
#  '방향',
#  '이',
#  '조',
#  '망',
#  '된다',
#  '.',
#  '왔던',
#  '방향',
#  '을',
#  '되돌아가서',
#  '오른쪽',
#  '지',
#  '양산',
#  '...',
#  '(',
#  '임',
#  '장기',
#  ')',
#  '까치산',
#  '공원',
#  '이',
#  '코앞',
#  '에',
#  '?',
#  '숲',
#  '세',
#  '권',
#  '사당',
#  '남',
#  '해오네',
#  '뜨',
#  '아파트',
#  '...',
#  '본',
#  '아파트',
#  '의',
#  '놀이터',
#  '는',
#  '아파트',
#  '에서',
#  '관리',
#  '하는',
#  '놀이터',
#  '가',
#  '아닌',
#  '구',
#  '에서',
#  '관리',
#  '하는',
#  '샛별',
#  '어린이',
#  '공원',
#  '입니',
#  '...',
#  '총',
#  '평',
#  '오늘',
#  '은',
# ...

# %%
str_txt = ''
for i in new_txt :
    str_txt = str_txt + i + ' '

# %%
from collections import Counter
Counter(new_txt).most_common()
# Out:
# [(',', 2008),
#  ('공원', 1883),
#  ('', 1650),
#  ('까치산', 1430),
#  ('...', 1306),
#  ('까치산역', 874),
#  ('.', 843),
#  ('이', 746),
#  ('에', 692),
#  ('근', 580),
#  ('린', 580),
#  ('을', 539),
#  ('빌라', 498),
#  ('서', 491),
#  ('-', 479),
#  ('(', 441),
#  ('화곡동', 436),
#  ('신축', 409),
#  (')', 350),
#  ('가', 332),
#  ('의', 329),
#  ('은', 326),
#  ('~', 314),
#  ('으로', 314),
#  ('과', 303),
#  ('2', 294),
#  ('등', 293),
#  ('에서', 287),
#  ('/', 287),
#  ('호선', 283),
#  (';', 262),
#  ('로', 250),
#  ('&', 243),
#  ('권', 231),
#  ('도', 223),
#  ('호수', 220),
#  ('한', 218),
#  ('강서구', 216),
#  (':', 209),
#  ('서울', 206),
#  ('울', 204),
#  ('시장', 204),
#  ('들', 202),
#  ('시설', 201),
#  ('5', 195),
#  ('를', 194),
#  ('아파트', 189),
#  ('도보', 187),
#  ('위치', 172),
#  ('3', 170),
#  ('역세', 170),
#  ('있는', 169),
#  ('[', 166),
#  ('화곡', 163),
#  ('1', 161),
#  ('는', 159),
#  ('룸', 157),
#  (']', 156),
#  ('입니다', 156),
#  ('산책', 151),
#  ('수', 149),
#  ('!', 134),
#  ('인근', 130),
#  ('거리', 123),
# ...

# %%
stop = [",", "공원", "", "까치산", "...", "이", "에"]
stopwords = set(stop)

# %%
stopwords.add("은")
stopwords.add("을")
stopwords.add("근린")
stopwords.add("에서")
stopwords.add("으로")
stopwords.add("의")
stopwords.add("서")
stopwords.add("등")
stopwords.add("과")
stopwords.add("가")
stopwords.add("도")
stopwords.add("는")
stopwords.add("를")
stopwords.add("로")
stopwords.add("입니다")
stopwords.add("와")

# %%
circle_mask = np.array(Image.open("picture.png")) # 배경이미지를 불러와서 numpy array로 변환

wc = WordCloud(font_path = 'C:/Users/sos35/AppData/Local/Microsoft/Windows/Fonts/NanumGothicBold.otf', max_font_size=100, max_words=100,
width=800, height=400, background_color="white",stopwords=stopwords, margin=10, random_state=1, contour_color='black').generate(str_txt)

wc.to_file("a_new_hope.png")
plt.axis("off")
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 우장근린공원

# %%
f = open('morph3_txt', 'r', encoding='UTF-8')
txt = f.readlines()
f.close()

# %%
new_txt = []
for i in txt :
    new_txt.append(i.replace('\n',''))

# %%
new_txt
# Out:
# ['[',
#  '♡',
#  ']',
#  '가족',
#  '힐링',
#  '하',
#  '는',
#  '우장',
#  '근',
#  '린',
#  '공',
#  '원',
#  '힐링',
#  '체험',
#  '센터',
#  '체험',
#  '(',
#  '간단',
#  '요약',
#  '...',
#  '#아이랑',
#  '#힐링체험',
#  '#우장산',
#  '#서울놀만한곳',
#  '#어린이체험',
#  '#우장산힐링',
#  '#',
#  '어린이',
#  '놀이터',
#  '#우장산체험',
#  '#우장근린공원',
#  '#아이랑체험',
#  '#우장산근린공원',
#  '#서울체험',
#  '#강서구체험',
#  '#강서구놀만한곳',
#  '#가족체험',
#  '#힐링체험센터',
#  '...',
#  '내',
#  '마음',
#  '은',
#  '충전',
#  '중',
#  ',',
#  '우장',
#  '근',
#  '린',
#  '공원',
#  '힐링',
#  '체험',
#  '센터',
#  '산림',
#  '치유',
#  '...',
#  '도심',
#  '속',
#  '의',
#  '휴식',
#  '쉼',
#  '터',
#  ',',
#  '우장',
#  '근',
#  '린',
#  '공원',
#  '힐링',
#  '체험',
#  '센터',
#  '에서',
#  '몸',
#  '과',
#  '마음',
#  '을',
#  '충전',
#  '할',
#  '수',
#  '있는',
#  '산림',
#  '치유',
#  '...',
#  '장소',
#  ':',
#  '우장',
#  '근',
#  '린',
#  '공원',
#  '힐링',
#  '체험',
#  '센터',
#  '(',
#  '강서구',
#  '화곡동',
#  '산',
#  '60-1',
#  ')',
#  '신청',
#  '방법',
#  ':',
#  '전화',
#  '(',
#  '02-2605',
#  '-',
#  '0959',
#  ')',
#  '또는',
# ...

# %%
str_txt = ''
for i in new_txt :
    str_txt = str_txt + i + ' '

# %%
from collections import Counter
Counter(new_txt).most_common()
# Out:
# [(',', 2109),
#  ('공원', 2023),
#  ('', 1880),
#  ('린', 1381),
#  ('근', 1380),
#  ('...', 1254),
#  ('우장', 876),
#  ('.', 694),
#  ('우장산', 659),
#  ('(', 603),
#  (')', 540),
#  ('강서구', 529),
#  ('이', 512),
#  ('과', 456),
#  ('의', 453),
#  ('에', 430),
#  (';', 429),
#  ('&', 415),
#  ('을', 401),
#  ('산책로', 358),
#  ('등', 355),
#  ('강서', 353),
#  ('길', 344),
#  ('단풍', 326),
#  ('서울', 318),
#  ('-', 304),
#  ('공', 300),
#  ('은', 297),
#  ('으로', 276),
#  ('~', 276),
#  ('화곡동', 263),
#  ('로', 260),
#  ('원', 254),
#  (':', 254),
#  ('시설', 253),
#  ('장', 230),
#  ('/', 224),
#  ('방화', 213),
#  ('체험', 210),
#  ('를', 201),
#  ('숲', 201),
#  ('빌라', 200),
#  ('가', 197),
#  ('한', 196),
#  ('에서', 194),
#  ('[', 187),
#  (']', 187),
#  ('화곡', 186),
#  ('센터', 173),
#  ('는', 163),
#  ('수', 161),
#  ('도', 154),
#  ('곳', 153),
#  ('2', 153),
#  ('초등학교', 150),
#  ('5', 150),
#  ('신축', 149),
#  ('원내', 147),
#  ('들', 135),
#  ('및', 134),
#  ('위치', 128),
#  ('구청', 126),
#  ('1', 124),
#  ('힐링', 122),
# ...

# %%
stop = [",", "공원", "", "린", "...", "근", "우장",".",")","("]
stopwords = set(stop)

# %%
stopwords.add("우장산")
stopwords.add("강서구")
stopwords.add("에")
stopwords.add("의")
stopwords.add("을")
stopwords.add("이")
stopwords.add("가")
stopwords.add("를")
stopwords.add("로")
stopwords.add("으로")
stopwords.add("도")
stopwords.add("강서")
stopwords.add("등")
stopwords.add("은")
stopwords.add("에서")
stopwords.add("과")
stopwords.add("는")
stopwords.add("입니다")
stopwords.add("공 원내")
stopwords.add("공 원내")
stopwords.add("와")
stopwords.add("있어")
stopwords.add("할 수")

# %%
from PIL import Image

circle_mask = np.array(Image.open("picture.png")) # 배경이미지를 불러와서 numpy array로 변환

wc = WordCloud(font_path = 'C:/Users/sos35/AppData/Local/Microsoft/Windows/Fonts/NanumGothicBold.otf', max_font_size=50, max_words=100,
width=800, height=400, background_color="white",stopwords=stopwords, margin=10, random_state=1, contour_color='black').generate(str_txt)

wc.to_file("a_new_hope.png")
plt.axis("off")
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
